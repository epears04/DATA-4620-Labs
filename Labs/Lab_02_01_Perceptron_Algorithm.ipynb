# %% [markdown]
# ### Lab 2.1: Perceptron Algorithm
#
# In this lab you will implement the perceptron algorithm presented in lecture using NumPy.

# %%
import numpy as np
from palmerpenguins import load_penguins
from mlxtend.plotting import plot_decision_regions
from matplotlib import pyplot as plt

# %% [markdown]
# Here we loading and format the Palmer penguins dataset for binary classification.

# %%
df = load_penguins()

# drop rows with missing values
df.dropna(inplace=True)

# tricky code to randomly shuffle the rows
df = df.sample(frac=1).reset_index(drop=True)

# select only two specices
df = df[(df['species']=='Adelie')|(df['species']=='Chinstrap')]

# get two features
X = df[['flipper_length_mm','bill_length_mm']].values

# convert speces labels to 0 and 1
y = df['species'].map({'Adelie':0,'Chinstrap':1}).values

# %% [markdown]
# To make the learning algorithm work more smoothly, we we will subtract the mean of each feature.
#
# Here `np.mean` calculates a mean, and `axis=0` tells NumPy to calculate the mean over the rows (calculate the mean of each column).

# %%
X -= np.mean(X,axis=0)

# %% [markdown]
# ### Exercises
#
# Your task is to complete this class for the perceptron.  Fill in the `train_step`, `predict`, and `score` functions.

# %%
class Perceptron:
    def __init__(self,lr=1e-3):
        # store the learning rate
        self.lr = lr

        # initialize the weights to small, normally-distributed values
        self.w = np.random.normal(size=(2,))*0.01

        # initialize the bias to zero
        self.b = 0

    def train_step(self,x,y):
        """ Apply the first update rule shown in lecture.
            Arguments:
             x: data point of shape (2,)
             y: label 
        """
        # WRITE CODE HERE
        # hint: first convert the y values to -1 or 1 using np.where
        y = np.where(y == 0, -1, y) # convert 0 (adelie) to -1
        self.w = self.w + self.lr * y * x    # w' = w + s*y*x
        self.b = self.b + self.lr * y    # b' = b + s*y
    
    def predict(self,X):
        """ Calculate model prediction for all data points.
            
            Arguments:
             X: data matrix of shape (N,2)   
            Returns:
             Predicted labels (0 or 1) of shape (N,)
        """
        # WRITE CODE HERE
        z = self.w @ X.T + self.b 
        return np.where(z < 0, 0, 1)
    
    def score(self,X,y):
        """ Calculate model accuracy
            Arguments:
             X: data matrix of shape (N,2)   
             y: labels of shape (N,)
            Returns:
             Accuracy score
        """
        # WRITE CODE HERE
        Z = self.predict(X)
        return np.mean(Z == y)

# %% [markdown]
# Run the following code to train the model and print out the accuracy at each step.

# %%
model = Perceptron()
for i in range(len(X)):
    model.train_step(X[i],y[i])
    print(f'step {i}: {model.score(X,y)}')
# Out:
# step 0: 0.6121495327102804
# step 1: 0.6728971962616822
# step 2: 0.705607476635514
# step 3: 0.7102803738317757
# step 4: 0.6915887850467289
# step 5: 0.6915887850467289
# step 6: 0.6915887850467289
# step 7: 0.7383177570093458
# step 8: 0.7383177570093458
# step 9: 0.7663551401869159
# step 10: 0.7710280373831776
# step 11: 0.7757009345794392
# step 12: 0.7757009345794392
# step 13: 0.7616822429906542
# step 14: 0.7663551401869159
# step 15: 0.7570093457943925
# step 16: 0.7710280373831776
# step 17: 0.7757009345794392
# step 18: 0.7757009345794392
# step 19: 0.780373831775701
# step 20: 0.780373831775701
# step 21: 0.780373831775701
# step 22: 0.780373831775701
# step 23: 0.780373831775701
# step 24: 0.780373831775701
# step 25: 0.780373831775701
# step 26: 0.780373831775701
# step 27: 0.780373831775701
# step 28: 0.780373831775701
# step 29: 0.780373831775701
# step 30: 0.780373831775701
# step 31: 0.780373831775701
# step 32: 0.780373831775701
# step 33: 0.780373831775701
# step 34: 0.780373831775701
# step 35: 0.780373831775701
# step 36: 0.780373831775701
# step 37: 0.7850467289719626
# step 38: 0.7850467289719626
# step 39: 0.7850467289719626
# step 40: 0.7897196261682243
# step 41: 0.794392523364486
# step 42: 0.794392523364486
# step 43: 0.7990654205607477
# step 44: 0.8084112149532711
# step 45: 0.8130841121495327
# step 46: 0.822429906542056
# step 47: 0.822429906542056
# step 48: 0.8130841121495327
# step 49: 0.8177570093457944
# step 50: 0.822429906542056
# step 51: 0.8130841121495327
# step 52: 0.794392523364486
# step 53: 0.8037383177570093
# step 54: 0.8037383177570093
# step 55: 0.794392523364486
# step 56: 0.794392523364486
# step 57: 0.794392523364486
# step 58: 0.794392523364486
# step 59: 0.794392523364486
# step 60: 0.794392523364486
# step 61: 0.7897196261682243
# step 62: 0.794392523364486
# step 63: 0.794392523364486
# step 64: 0.794392523364486
# step 65: 0.794392523364486
# step 66: 0.794392523364486
# step 67: 0.794392523364486
# step 68: 0.794392523364486
# step 69: 0.7897196261682243
# step 70: 0.794392523364486
# step 71: 0.794392523364486
# step 72: 0.794392523364486
# step 73: 0.794392523364486
# step 74: 0.794392523364486
# step 75: 0.794392523364486
# step 76: 0.794392523364486
# step 77: 0.794392523364486
# step 78: 0.794392523364486
# step 79: 0.794392523364486
# step 80: 0.794392523364486
# step 81: 0.794392523364486
# step 82: 0.794392523364486
# step 83: 0.794392523364486
# step 84: 0.794392523364486
# step 85: 0.7897196261682243
# step 86: 0.794392523364486
# step 87: 0.794392523364486
# step 88: 0.794392523364486
# step 89: 0.794392523364486
# step 90: 0.794392523364486
# step 91: 0.794392523364486
# step 92: 0.794392523364486
# step 93: 0.794392523364486
# step 94: 0.794392523364486
# step 95: 0.794392523364486
# step 96: 0.794392523364486
# step 97: 0.794392523364486
# step 98: 0.794392523364486
# step 99: 0.794392523364486
# step 100: 0.794392523364486
# step 101: 0.794392523364486
# step 102: 0.794392523364486
# step 103: 0.794392523364486
# step 104: 0.794392523364486
# step 105: 0.794392523364486
# step 106: 0.794392523364486
# step 107: 0.794392523364486
# step 108: 0.7990654205607477
# step 109: 0.8037383177570093
# step 110: 0.8084112149532711
# step 111: 0.8084112149532711
# step 112: 0.8084112149532711
# step 113: 0.8084112149532711
# step 114: 0.8084112149532711
# step 115: 0.8084112149532711
# step 116: 0.8130841121495327
# step 117: 0.8084112149532711
# step 118: 0.8084112149532711
# step 119: 0.8084112149532711
# step 120: 0.8084112149532711
# step 121: 0.8084112149532711
# step 122: 0.8130841121495327
# step 123: 0.8177570093457944
# step 124: 0.822429906542056
# step 125: 0.822429906542056
# step 126: 0.8271028037383178
# step 127: 0.8271028037383178
# step 128: 0.8271028037383178
# step 129: 0.8317757009345794
# step 130: 0.8271028037383178
# step 131: 0.8271028037383178
# step 132: 0.8271028037383178
# step 133: 0.8271028037383178
# step 134: 0.8271028037383178
# step 135: 0.8271028037383178
# step 136: 0.8271028037383178
# step 137: 0.8271028037383178
# step 138: 0.822429906542056
# step 139: 0.8271028037383178
# step 140: 0.822429906542056
# step 141: 0.8130841121495327
# step 142: 0.8084112149532711
# step 143: 0.8130841121495327
# step 144: 0.8130841121495327
# step 145: 0.8130841121495327
# step 146: 0.8130841121495327
# step 147: 0.8084112149532711
# step 148: 0.8130841121495327
# step 149: 0.8130841121495327
# step 150: 0.8084112149532711
# step 151: 0.8084112149532711
# step 152: 0.7990654205607477
# step 153: 0.7990654205607477
# step 154: 0.794392523364486
# step 155: 0.7990654205607477
# step 156: 0.8084112149532711
# step 157: 0.8037383177570093
# step 158: 0.8037383177570093
# step 159: 0.7990654205607477
# step 160: 0.7990654205607477
# step 161: 0.8084112149532711
# step 162: 0.8084112149532711
# step 163: 0.8084112149532711
# step 164: 0.8084112149532711
# step 165: 0.8084112149532711
# step 166: 0.8130841121495327
# step 167: 0.8130841121495327
# step 168: 0.8130841121495327
# step 169: 0.8130841121495327
# step 170: 0.8130841121495327
# step 171: 0.8130841121495327
# step 172: 0.8130841121495327
# step 173: 0.822429906542056
# step 174: 0.8177570093457944
# step 175: 0.8177570093457944
# step 176: 0.8271028037383178
# step 177: 0.8271028037383178
# step 178: 0.8271028037383178
# step 179: 0.8271028037383178
# step 180: 0.8271028037383178
# step 181: 0.822429906542056
# step 182: 0.8271028037383178
# step 183: 0.822429906542056
# step 184: 0.8177570093457944
# step 185: 0.8177570093457944
# step 186: 0.822429906542056
# step 187: 0.822429906542056
# step 188: 0.822429906542056
# step 189: 0.8271028037383178
# step 190: 0.8271028037383178
# step 191: 0.8271028037383178
# step 192: 0.8317757009345794
# step 193: 0.8317757009345794
# step 194: 0.8317757009345794
# step 195: 0.8317757009345794
# step 196: 0.8317757009345794
# step 197: 0.8317757009345794
# step 198: 0.8317757009345794
# step 199: 0.8317757009345794
# step 200: 0.8317757009345794
# step 201: 0.8317757009345794
# step 202: 0.8317757009345794
# step 203: 0.8317757009345794
# step 204: 0.8317757009345794
# step 205: 0.8317757009345794
# step 206: 0.8317757009345794
# step 207: 0.8317757009345794
# step 208: 0.8317757009345794
# step 209: 0.8317757009345794
# step 210: 0.8317757009345794
# step 211: 0.8317757009345794
# step 212: 0.8317757009345794
# step 213: 0.8317757009345794

# %% [markdown]
# Finally we plot the decision regions.

# %%
plot_decision_regions(X, y, clf=model, legend=0, markers='o')
# Out:
# <Axes: >
